# %% [markdown]
# <a href="https://colab.research.google.com/github/evelyncos/inteligencia_artificial/blob/main/acidentes_a%C3%A9reos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.model_selection import train_test_split

URL = "https://raw.githubusercontent.com/paulozip/acidentes-aereos/master/dataset/ocorrencia.csv"

# %%
dados = pd.read_csv(URL)
dados.head()
# Out:
#    codigo_ocorrencia    classificacao                       tipo  localidade  \
# 0              47965         ACIDENTE      FALHA DO MOTOR EM VOO   ARIQUEMES
# 1              50313  INCIDENTE GRAVE             POUSO SEM TREM      CACOAL
# 2              34078         ACIDENTE  PERDA DE CONTROLE NO SOLO  CEREJEIRAS
# 3              44988         ACIDENTE                POUSO LONGO     AMAJARI
# 4              38855         ACIDENTE   PERDA DE CONTROLE EM VOO      ACEGUÁ
#
#    uf    pais aerodromo dia_ocorrencia   horario sera_investigada  \
# 0  RO  BRASIL      SJOG     2013-05-05  11:00:00              ***
# 1  RO  BRASIL      SSKW     2013-11-25  12:32:00              SIM
# 2  RO  BRASIL      ****     2008-08-07  15:10:00              SIM
# 3  RR  BRASIL      ****     2011-08-11  17:00:00              SIM
# 4  RS  BRASIL      ****     2009-12-28  17:30:00              SIM
#
#   comando_investigador status_investigacao     numero_relatorio  \
# ...

# %%
#apagar colunas

dados = dados.drop(columns = ["codigo_ocorrencia","classificacao","tipo","uf","localidade","pais","aerodromo","status_investigacao","comando_investigador","numero_relatorio","relatorio_publicado","quantidade_recomendacoes","quantidade_recomendacoes","dia_publicacao","saida_pista"], axis = 1)
dados.head()
# Out:
#   dia_ocorrencia   horario sera_investigada  aeronaves_envolvidas dia_extracao
# 0     2013-05-05  11:00:00              ***                     1   2016-07-30
# 1     2013-11-25  12:32:00              SIM                     1   2016-07-30
# 2     2008-08-07  15:10:00              SIM                     1   2016-07-30
# 3     2011-08-11  17:00:00              SIM                     1   2016-07-30
# 4     2009-12-28  17:30:00              SIM                     1   2016-07-30

# %%
#troca de dados (sera_investigada)
a_trocar = {
    "NAO" : 0,
    "SIM" : 1
}
dados.sera_investigada= dados.sera_investigada.map(a_trocar)
dados.head()
# Out:
#   dia_ocorrencia   horario  sera_investigada  aeronaves_envolvidas  \
# 0     2013-05-05  11:00:00               NaN                     1
# 1     2013-11-25  12:32:00               1.0                     1
# 2     2008-08-07  15:10:00               1.0                     1
# 3     2011-08-11  17:00:00               1.0                     1
# 4     2009-12-28  17:30:00               1.0                     1
#
#   dia_extracao
# 0   2016-07-30
# 1   2016-07-30
# 2   2016-07-30
# 3   2016-07-30
# 4   2016-07-30

# %%
#fatiando os dados
x = dados[["dia_ocorrencia", "horario","horario"]]
y = dados ["sera_investigada"]

SEED = 20
np.random.seed(SEED)
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.30)
                                                      
print(f"Treinamento: {len(treino_x)} | Teste: {len(teste_x)}")
# Out:
# Treinamento: 1418 | Teste: 609

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

modelo = LinearSVC()
modelo.fit(treino_x, treino_y)

previsoes = modelo.predict (teste_x)

acuracia = accuracy_score(teste_y, previsoes)*100
print (f"Acuracia : {acuracia:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-d0a4de6c279d> in <module>()
#       3
#       4 modelo = LinearSVC()
# ----> 5 modelo.fit(treino_x, treino_y)
#       6
#       7 previsoes = modelo.predict (teste_x)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_classes.py in fit(self, X, y, sample_weight)
#     250             dtype=np.float64,
#     251             order="C",
# --> 252             accept_large_sparse=False,
#     253         )
#     254         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...
